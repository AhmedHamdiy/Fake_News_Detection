# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay,accuracy_score

data_file = './DataSet/news_articles.csv'
df = pd.read_csv(data_file)
x_train, x_test, y_train, y_test = train_test_split(df[['hasImage']], df['label'], test_size=0.2)
model = GaussianNB()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)
model.fit(x_train, y_train)  
predictions = model.predict(x_test)
accuracy= accuracy_score(y_test,y_pred)
print("Accuracy",accuracy)
print(classification_report(y_test, predictions))
# Out:
# Accuracy 0.5301204819277109
#               precision    recall  f1-score   support
#
#         Fake       0.55      0.25      0.34       164
#         Real       0.52      0.80      0.63       168
#
#     accuracy                           0.53       332
#    macro avg       0.54      0.53      0.49       332
# weighted avg       0.54      0.53      0.49       332

# %%
cm=confusion_matrix(y_pred,y_test)
disp = ConfusionMatrixDisplay(confusion_matrix = cm,display_labels=model.classes_)
disp.plot()
